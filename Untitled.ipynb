# %%
import os

# %%
os.system("ssh user@10.186.165.72 r'C:\Users\user\12. OMNIBUS-IMED integration\TEST.py'")
# Out:
# KeyboardInterrupt

# %%
print(r'C:\Users\user\12. OMNIBUS-IMED integration\TEST.py')
# Out:
# C:\Users\user\12. OMNIBUS-IMED integration\TEST.py
